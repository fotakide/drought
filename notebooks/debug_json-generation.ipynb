# %%
import os
from pathlib import Path
import datetime
import json
import logging
import argparse

# %%
def generate_json_files_for_composites(
    output_dir="../jsons/compgen",
    tile_geojson_filepath='../anciliary/grid_v2.geojson',
    start_date: datetime.datetime=datetime.datetime(2020, 1, 1),
    end_date: datetime.datetime=datetime.datetime(2025, 9, 1),
    ):
    
    os.makedirs(output_dir, exist_ok=True)
    
    current_date = start_date
    while current_date <= end_date:
        year_month = current_date.strftime("%Y-%m")
        file_prefix = current_date.strftime("%Y%m")
        
        data = {
            "year_month": year_month,
            "tilegrid_path": tile_geojson_filepath
        }
            
        file_name = f"compgen_{file_prefix}.json"
        file_path = os.path.join(output_dir, file_name)
        
        with open(file_path, "w") as f:
            json.dump(data, f, indent=4)
        
        print(f"Saved: {file_path}")
        
        # Move to the next month
        current_date += datetime.timedelta(days=32)
        current_date = current_date.replace(day=1)  # Ensure we are at the first of the month

# %%
generate_json_files_for_composites()
# Out:
# Saved: ../jsons/compgen\compgen_202001.json
# Saved: ../jsons/compgen\compgen_202002.json
# Saved: ../jsons/compgen\compgen_202003.json
# Saved: ../jsons/compgen\compgen_202004.json
# Saved: ../jsons/compgen\compgen_202005.json
# Saved: ../jsons/compgen\compgen_202006.json
# Saved: ../jsons/compgen\compgen_202007.json
# Saved: ../jsons/compgen\compgen_202008.json
# Saved: ../jsons/compgen\compgen_202009.json
# Saved: ../jsons/compgen\compgen_202010.json
# Saved: ../jsons/compgen\compgen_202011.json
# Saved: ../jsons/compgen\compgen_202012.json
# Saved: ../jsons/compgen\compgen_202101.json
# Saved: ../jsons/compgen\compgen_202102.json
# Saved: ../jsons/compgen\compgen_202103.json
# Saved: ../jsons/compgen\compgen_202104.json
# Saved: ../jsons/compgen\compgen_202105.json
# Saved: ../jsons/compgen\compgen_202106.json
# Saved: ../jsons/compgen\compgen_202107.json
# Saved: ../jsons/compgen\compgen_202108.json
# Saved: ../jsons/compgen\compgen_202109.json
# Saved: ../jsons/compgen\compgen_202110.json
# Saved: ../jsons/compgen\compgen_202111.json
# Saved: ../jsons/compgen\compgen_202112.json
# Saved: ../jsons/compgen\compgen_202201.json
# Saved: ../jsons/compgen\compgen_202202.json
# Saved: ../jsons/compgen\compgen_202203.json
# Saved: ../jsons/compgen\compgen_202204.json
# Saved: ../jsons/compgen\compgen_202205.json
# Saved: ../jsons/compgen\compgen_202206.json
# Saved: ../jsons/compgen\compgen_202207.json
# Saved: ../jsons/compgen\compgen_202208.json
# Saved: ../jsons/compgen\compgen_202209.json
# Saved: ../jsons/compgen\compgen_202210.json
# Saved: ../jsons/compgen\compgen_202211.json
# Saved: ../jsons/compgen\compgen_202212.json
# Saved: ../jsons/compgen\compgen_202301.json
# Saved: ../jsons/compgen\compgen_202302.json
# Saved: ../jsons/compgen\compgen_202303.json
# Saved: ../jsons/compgen\compgen_202304.json
# Saved: ../jsons/compgen\compgen_202305.json
# Saved: ../jsons/compgen\compgen_202306.json
# Saved: ../jsons/compgen\compgen_202307.json
# Saved: ../jsons/compgen\compgen_202308.json
# Saved: ../jsons/compgen\compgen_202309.json
# Saved: ../jsons/compgen\compgen_202310.json
# Saved: ../jsons/compgen\compgen_202311.json
# Saved: ../jsons/compgen\compgen_202312.json
# Saved: ../jsons/compgen\compgen_202401.json
# Saved: ../jsons/compgen\compgen_202402.json
# Saved: ../jsons/compgen\compgen_202403.json
# Saved: ../jsons/compgen\compgen_202404.json
# Saved: ../jsons/compgen\compgen_202405.json
# Saved: ../jsons/compgen\compgen_202406.json
# Saved: ../jsons/compgen\compgen_202407.json
# Saved: ../jsons/compgen\compgen_202408.json
# Saved: ../jsons/compgen\compgen_202409.json
# Saved: ../jsons/compgen\compgen_202410.json
# Saved: ../jsons/compgen\compgen_202411.json
# Saved: ../jsons/compgen\compgen_202412.json
# Saved: ../jsons/compgen\compgen_202501.json
# Saved: ../jsons/compgen\compgen_202502.json
# Saved: ../jsons/compgen\compgen_202503.json
# Saved: ../jsons/compgen\compgen_202504.json
# Saved: ../jsons/compgen\compgen_202505.json
# Saved: ../jsons/compgen\compgen_202506.json
# Saved: ../jsons/compgen\compgen_202507.json
# Saved: ../jsons/compgen\compgen_202508.json
# Saved: ../jsons/compgen\compgen_202509.json
